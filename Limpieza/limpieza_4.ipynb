# %% [markdown]
# ### Limpieza_4
# ___

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable

# %%
df = pd.read_csv("data/bank_clean3.csv", index_col = 0)
pd.options.display.max_columns = None
df.head(1)
# Out:
#     age        job  marital education default housing loan    contact  \
# 0  56.0  housemaid  married       NaN      No      No   No  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261       1.0    999         0  nonexistent           NaN
#
#    cons,price,idx  cons,conf,idx  euribor3m nr,employed   y month_day_week  \
# 0          93.994          -36.4      4.857      5191,0  no       may, mon
#
#   month   day
# 0   may   mon

# %% [markdown]
# 1. Lo primero que tenemos que evaluar es en que columnas tenemos nulos y que cantidad tenemos en cada una.
#
# - ¿Hay alguna columna con una gran cantidad de nulos? En caso de que sea así deberemos eliminarla.

# %%
df.stb.missing()
# Out:
#                 missing  total    percent
# education         13943  41186  33.853737
# emp,var,rate      12771  41186  31.008110
# y                 12751  41186  30.959549
# loan               8942  41186  21.711261
# default            8597  41186  20.873598
# marital            8203  41186  19.916962
# job                4591  41186  11.146992
# age                4302  41186  10.445297
# cons,price,idx     4300  41186  10.440441
# housing             990  41186   2.403729
# campaign            432  41186   1.048900
# euribor3m             0  41186   0.000000
# month                 0  41186   0.000000
# month_day_week        0  41186   0.000000
# nr,employed           0  41186   0.000000
# previous              0  41186   0.000000
# cons,conf,idx         0  41186   0.000000
# poutcome              0  41186   0.000000
# pdays                 0  41186   0.000000
# duration              0  41186   0.000000
# contact               0  41186   0.000000
# ...

# %% [markdown]
# No creemos que haya ninguan columna con una cantidad de nulos que justifique eliminarla. El mayor porcentaje de nulos lo encontramos en la columna education, con un 33,8%.

# %% [markdown]
# 2. Es el momento de eliminar los nulos:
#
# - Reemplazad los valores nulos de las columnas age y campaign por la media, redondeada a dos decimales.

# %%
df[['age', 'campaign']].describe().T
# Out:
#             count       mean       std   min   25%   50%   75%   max
# age       36884.0  39.555146  9.603396  17.0  32.0  38.0  46.0  69.0
# campaign  40754.0   2.040757  1.242130   1.0   1.0   2.0   3.0   6.0

# %%
df[['age', 'campaign']].mean().round(2)
# Out:
# age         39.56
# campaign     2.04
# dtype: float64

# %%
df['age'].fillna(df['age'].mean().round(2), inplace = True)
df['campaign'].fillna(df['campaign'].mean().round(2), inplace = True)

# %%
df[['age', 'campaign']].describe().T
# Out:
#             count       mean       std   min   25%   50%   75%   max
# age       41186.0  39.555653  9.088003  17.0  33.0  39.0  45.0  69.0
# campaign  41186.0   2.040749  1.235599   1.0   1.0   2.0   3.0   6.0

# %%
df.stb.missing()
# Out:
#                 missing  total    percent
# education         13943  41186  33.853737
# emp,var,rate      12771  41186  31.008110
# y                 12751  41186  30.959549
# loan               8942  41186  21.711261
# default            8597  41186  20.873598
# marital            8203  41186  19.916962
# job                4591  41186  11.146992
# cons,price,idx     4300  41186  10.440441
# housing             990  41186   2.403729
# age                   0  41186   0.000000
# cons,conf,idx         0  41186   0.000000
# month                 0  41186   0.000000
# month_day_week        0  41186   0.000000
# nr,employed           0  41186   0.000000
# euribor3m             0  41186   0.000000
# previous              0  41186   0.000000
# poutcome              0  41186   0.000000
# pdays                 0  41186   0.000000
# campaign              0  41186   0.000000
# duration              0  41186   0.000000
# contact               0  41186   0.000000
# ...

# %% [markdown]
# - Reemplazad los valores nulos de la columna emp.var.rate y cons.price.idx por la mediana de cada una de estas columnas, redondeada a dos decimales.

# %%
df['emp,var,rate'].fillna(df['emp,var,rate'].median().round(2), inplace = True)
df['cons,price,idx'].fillna(df['cons,price,idx'].median().round(2), inplace = True)

# %%
df.stb.missing()
# Out:
#                 missing  total    percent
# education         13943  41186  33.853737
# y                 12751  41186  30.959549
# loan               8942  41186  21.711261
# default            8597  41186  20.873598
# marital            8203  41186  19.916962
# job                4591  41186  11.146992
# housing             990  41186   2.403729
# age                   0  41186   0.000000
# cons,price,idx        0  41186   0.000000
# month                 0  41186   0.000000
# month_day_week        0  41186   0.000000
# nr,employed           0  41186   0.000000
# euribor3m             0  41186   0.000000
# cons,conf,idx         0  41186   0.000000
# previous              0  41186   0.000000
# emp,var,rate          0  41186   0.000000
# poutcome              0  41186   0.000000
# pdays                 0  41186   0.000000
# campaign              0  41186   0.000000
# duration              0  41186   0.000000
# contact               0  41186   0.000000
# ...

# %% [markdown]
# - En relación a las columnas de education, default, housing y loan al tratarse de columnas de tipo categórica, reemplazad los valores nulos por una nueva categória que se llame unknown.

# %%
df[['education', 'default', 'housing', 'loan']] = df[['education', 'default', 'housing', 'loan']].replace(np.nan, 'unknown')

# %%
df.stb.missing()
# Out:
#                 missing  total    percent
# y                 12751  41186  30.959549
# marital            8203  41186  19.916962
# job                4591  41186  11.146992
# age                   0  41186   0.000000
# poutcome              0  41186   0.000000
# month                 0  41186   0.000000
# month_day_week        0  41186   0.000000
# nr,employed           0  41186   0.000000
# euribor3m             0  41186   0.000000
# cons,conf,idx         0  41186   0.000000
# cons,price,idx        0  41186   0.000000
# emp,var,rate          0  41186   0.000000
# previous              0  41186   0.000000
# pdays                 0  41186   0.000000
# campaign              0  41186   0.000000
# duration              0  41186   0.000000
# contact               0  41186   0.000000
# loan                  0  41186   0.000000
# housing               0  41186   0.000000
# default               0  41186   0.000000
# education             0  41186   0.000000
# ...

# %% [markdown]
# - Reemplazad los valores nulos de las columna job y marital por el valor más frecuente (la moda).

# %%
df[['job', 'marital']].mode()
# Out:
#               job  marital
# 0  administration  married

# %%
df['job'].replace(np.nan, df['job'].mode()[0], inplace = True)
df['marital'].replace(np.nan, df['marital'].mode()[0], inplace = True)

# %%
df.stb.missing()
# Out:
#                 missing  total    percent
# y                 12751  41186  30.959549
# age                   0  41186   0.000000
# job                   0  41186   0.000000
# month                 0  41186   0.000000
# month_day_week        0  41186   0.000000
# nr,employed           0  41186   0.000000
# euribor3m             0  41186   0.000000
# cons,conf,idx         0  41186   0.000000
# cons,price,idx        0  41186   0.000000
# emp,var,rate          0  41186   0.000000
# poutcome              0  41186   0.000000
# previous              0  41186   0.000000
# pdays                 0  41186   0.000000
# campaign              0  41186   0.000000
# duration              0  41186   0.000000
# contact               0  41186   0.000000
# loan                  0  41186   0.000000
# housing               0  41186   0.000000
# default               0  41186   0.000000
# education             0  41186   0.000000
# marital               0  41186   0.000000
# ...

# %% [markdown]
# - Nos quedan la columna y. ¿Qué tipo de variable es? Decidid cual sería la mejor gestión de nulos para esta columna.

# %%
df.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# duration            int64
# campaign          float64
# pdays               int64
# previous            int64
# poutcome           object
# emp,var,rate      float64
# cons,price,idx    float64
# cons,conf,idx     float64
# euribor3m         float64
# nr,employed        object
# y                  object
# month_day_week     object
# month              object
# day                object
# dtype: object

# %%
df['y'].value_counts()
# Out:
# y
# no     25294
# yes     3141
# Name: count, dtype: int64

# %%
df[df['y'].isnull()]
# Out:
#          age             job   marital            education  default housing  \
# 2      37.00        services   married          high school       No      Sí
# 5      45.00        services   married             basic 9y  unknown      No
# 11     39.56        services    single              unknown       No      Sí
# 13     57.00       housemaid  divorced             basic 4y       No      Sí
# 18     50.00  administration   married              unknown       No      Sí
# ...      ...             ...       ...                  ...      ...     ...
# 41170  40.00      management  divorced    university degree       No      Sí
# 41172  39.56  administration   married    university degree       No      Sí
# 41174  62.00         retired   married              unknown       No      Sí
# 41180  36.00  administration   married    university degree       No      No
# 41186  44.00      technician   married  professional course       No      No
#
# ...

# %% [markdown]
# Debido a los datos que tenemos, hemos decidido cambiar los nulos por una nueva categoría (unknown), y no sustituirlo por la moda, ya que tenemos solo dos valores para esa columna ( no y yes), y nuestros datos podrían verse muy afectados.

# %%
df['y'] = df['y'].replace(np.nan, 'unknown')

# %%
df.stb.missing()
# Out:
#                 missing  total  percent
# age                   0  41186      0.0
# job                   0  41186      0.0
# month                 0  41186      0.0
# month_day_week        0  41186      0.0
# y                     0  41186      0.0
# nr,employed           0  41186      0.0
# euribor3m             0  41186      0.0
# cons,conf,idx         0  41186      0.0
# cons,price,idx        0  41186      0.0
# emp,var,rate          0  41186      0.0
# poutcome              0  41186      0.0
# previous              0  41186      0.0
# pdays                 0  41186      0.0
# campaign              0  41186      0.0
# duration              0  41186      0.0
# contact               0  41186      0.0
# loan                  0  41186      0.0
# housing               0  41186      0.0
# default               0  41186      0.0
# education             0  41186      0.0
# marital               0  41186      0.0
# day                   0  41186      0.0

# %% [markdown]
# 3. Guardad el csv.

# %%
df.to_csv('data/bank_clean4.csv')
